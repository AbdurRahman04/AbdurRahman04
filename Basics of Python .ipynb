# %% [markdown]
# # Basics of Python

# %% [markdown]
# ## Opertors
# ### Operators are special symbols in Python that carry out arithmetic or logical computation. The value that the operator operates on is called the operand
# ### Exapmles:
# - print(2+ 3)
# - print(5-9)
# - print(2*8)
# - print(9/7)
# - print(17%3)
# - print(9//7)
# - print(3 ** 5 )
# - print(2**3/2*3/5+7-3/8*9)

# %% [markdown]
# ## String
# ### String is a collection of alphabets, words or other characters. It is one of the primitive data structures and are the building blocks for data manipulation. Python has a built-in string class named str . Python strings are "immutable" which means they cannot be changed after they are created.
# ### Exapmles:
# - print("we learn with ammar ali chila ")
# - print('ali is a good boy ')
# - print('''she is prety girl''')

# %% [markdown]
# ## Comment
# ### A comment in Python starts with the hash character, # , and extends to the end of the physical line. A hash character within a string value is not seen as a comment, though. To be precise, a comment can be written in three ways - entirely on its own line, next to a statement of code, and as a multi-line comment block
# ### Examples:
# - print("where you live?")
# - print ("what is your name?")
# - print(2+3)#use addition operator to ads values

# %% [markdown]
# ## Variables
# ### A Python variable is a reserved memory location to store values. In other words, a variable in a python program gives data to the computer for processing. Every value in Python has a datatype. Different data types in Python are Numbers, List, Tuple, Strings, Dictionary, etc.
# ### Examples:
# ### variables:object contaning specific values
# - x=9+8 #numeric or integer variables
# - print(x)
#
# - y="my name is abdur rahman" #for string variables
# - print(y)
#
#
# - x=x+8 # or x=25\
# - print(x)
#
#
# ### types of varibale
# - type (x)\
# - print(type(x))
#
# - print(type(y))
#
# ## Rules of  assign a variable
#
# 1: the variable should contain letters,numbers or underscore
# 2: Donot start with numbers
# 3: spaces are not allowed
# 4: donot use functional key words
# 5: variable name should be short and discriptive
# 6: case sensitvity(lowercaes letters and upercase letters ka both khyal rakhna parta h .

# %% [markdown]
# ### Input_funtion(simple)
# - furit_basket=input("which is your favert fruiit? ")
# - print(furit_basket)
#
#
# ### Input_function of 2nd satage
# - name=input("what is your name? ")
# - greeting="helo!"
# - print(greeting,name)
#
# ### Another way of stage 2 method
# - name=input("what is your name? ")
# - print("helo!",name)
#
#
# ### 3rd stage input function
# - name=input("what is your name? ")
# - age=input("how much you old? ")
# ### Comment="you are still young"
# - print("helo! " ,name, "you are still young")

# %% [markdown]
# ## Conditional  Operator
# ###  Logical operators or either "true/false,yes/no,0/1"
# ### Conditional operators are
# - equal to                      ==
# - not equal to                  !=
# - greater then                  >
# - less then                     <
# - less then and equal to        <=
# - greater then and equal to     >=
#
# ### Exaples:
# - is four eqal to four
# - print(4==4)
# - print(4!=4)
# - print(4>3)
# - print(4<3)
# - print(4<=3)
# - print(4>=3)
#
# ### Application of logical oprators
#
# ali_age=input("what is of age ali ? ")\
# ali_age=int(ali_age)\
# require_age=5\
# print(ali_age>=require_age)\
# print(type(ali_age))
# ### On different website they ask  age limit question then behind this question a conditional oprator is working.

# %% [markdown]
# ## Conversion
# ### Data types can be converted either implicitly or explicitly. Implicit conversions are not visible to the user. SQL Server automatically converts the data from one data type to another. For example, when a smallint is compared to an int, the smallint is implicitly converted to int before the comparison proceeds
# - x=5                                            integee
# - y=5.10                                         float
# - z="helo!dear"                                  string
# print(type(x))\
# print(type(y))\
# print(type(z))
#
# ### Implict type of conversion
# * x=x*y \
# print(x,"type of x is ",type(x))
#
# ### Explict type of conversion
# * age=input("wahtr is your age ? ")
# * age=int(age) \
# print(age,type((float(age))))

# %% [markdown]
# ### There comes situations in real life when we need to make some decisions and based on these decisions, we decide what should we do next. Similar situations arise in programming also where we need to make some decisions and based on these decisions we will execute the next block of code. Decision-making statements in programming languages decide the direction of the flow of program execution.
# ## if-else
# ### The if statement alone tells us that if a condition is true it will execute a block of statements and if the condition is false it won’t. But what if we want to do something else if the condition is false. Here comes the else statement. We can use the else statement with if statement to execute a block of code when the condition is false.
# ## if-elif-else
# ### Here, a user can decide among multiple options. The if statements are executed from the top down. As soon as one of the conditions controlling the if is true, the statement associated with that if is executed, and the rest of the ladder is bypassed. If none of the conditions is true, then the final else statement will be executed.
#
# ali_age=input("what is of age ali ? ")\
# ali_age=int(ali_age)\
# require_age=5\
# if ali_age==require_age:\
#     print("ali can join the school")\
# elif ali_age>require_age:\
#     print("ali should join college")\
# elif ali_age==2:\
#     print("ali should not join any institute")\
# else:\
#     print("ali can not join the school")

# %% [markdown]
# #### if we wnat to print same string many time then it is kjto difficult to print becuse this is time conusming process
# #### for example
# print("how old are you")\
# print("how old are you")\
# print("how old are you")\
# print("how old are you")\
# print("how old are you")\
# print("how old are you")\
# print("how old are you")
# #### so to over come our time consumption we define a function that sovle our problem in few second
#
# ### Mthod No 01
# def print_df():\
# print("how old are you")\
# print("how old are you")\
# print("how old are you")\
# print_df()\
#
# ### Method No 02
#
# def print_df():\
# text ="how you are old"\
# print(text)\
# print(text)\
# print(text)\
# print_df()\
# ### Method No 03
#
# def print_df(text):\
# print(text)\
# print(text)\
# print(text)\
# print_df("i love machine learning")\
#
# ### Method No 04
# #### defining a function by using if,else,elif statement
# def school_calculator(age):\
# if age==5:\
# print("ali can go to school")\
# elif age>5:\
# print("ali can go to higher school")\
# else:\
# print("ali is still baby")\
# school_calculator(3)\
#
# def future_age(age):\
#     new_age=age+20\
#     return new_age\
#     print(new_age)\
# pridected_future_age=future_age(18)\
# print(pridected_future_age)\

# %% [markdown]
# ## Loops
# ### When you want some statements to execute a hundred times, you don’t repeat them 100 times.Think of when you want to print numbers 1 to 99. Or that you want to say Hello to 99 friends.
# #### In such a case, you can use loops.
# #### Here, we will discuss 4 types of Python Loop:
#
# - For Loop
# - While Loop
# - Loop Control Statements
# - Nested For Loop
# ### While Loop
# #### A while loop in python iterates till its condition becomes False. In other words, it executes the statements under itself while the condition it takes is True.When the program control reaches the while loop, the condition is checked. If the condition is true, the block of code under it is executed.Remember to indent all statements under the loop equally. After that, the condition is checked again.This continues until the condition becomes false.
#
# x=1\
# y=input("table of=" )\
# y=int(y)
# while (x<10):\
# print("x*y=",x*y)\
# x=x+1
# ### For Loop
# #### Python for loop can iterate over a sequence of items. The structure of a for loop in Python is different than that in C++ or Java.
#
# #### That is, for(int i=0;i<n;i++) won’t work here. In Python, we use the ‘in’ keyword.
# for x in range(4,12):\
#    print(x)
